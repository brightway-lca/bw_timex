# %% [markdown]
# # Time-explicit LCA of an electric vehicle

# %% [markdown]
# This notebook shows how to use `timex_lca` with a cradle-to-grave case study of an electric vehicle. The case study is simplified, not meant to reflect the complexity of electric mobility but to demonstrate hot to use `timex_lca`.
#
# More information on the inner workings of `timex_lca` can be found [here](https://timex.readthedocs.io/en/latest/content/theory.html).

# %%
import bw2data as bd

bd.projects.set_current("bw25_premise")

# %% [markdown]
# ## Prospective databases
#
# Created using [Ecoinvent v3.9](https://ecoinvent.org/)  and [`premise`](https://github.com/polca/premise), with projections for the future electricity sectors using the SSP2-RCP19 pathway from the IAM IMAGE.

# %%
db_2020 = bd.Database("db_2020")
db_2030 = bd.Database("db_2030")
db_2040 = bd.Database("db_2040")

# %% [markdown]
# ## Case study setup

# %% [markdown]
# Let's make sure we start from scratch:

# %%
del bd.databases["foreground"]
foreground = bd.Database("foreground")
foreground.write({})

# %% [markdown]
# Getting the input processes of the EV from the background database:

# %%
glider_production = bd.get_activity(("db_2020", "133b33cc867081af144475d62179286b"))
powertrain_production = bd.get_activity(
    ("db_2020", "f6d3f0b01e4a38c055e3c5c1356a4bba")
)  # eol included
battery_production = bd.get_activity(("db_2020", "ba87aff6361d99be2636e8c59e55a5b2"))
electricity_production = bd.get_activity(
    ("db_2020", "fec93a95a9a84d7fa0ede9c3082bb79f")
)
glider_eol = bd.get_activity(("db_2020", "f8114e0ff375b3c6d72ccfa49f79e44d"))
battery_eol = bd.get_activity(("db_2020", "82ebcdf42e8512cbe00151dda6210d29"))

# %% [markdown]
# Creating the EV activity:

# %%
fg = bd.Database("foreground")

# %%
fg.new_node("EV_lifecycle", name="Electric vehicle, lifecycle", unit="unit").save()
ev_lifecycle = fg.get("EV_lifecycle")

# %% [markdown]
# Here are some parameter assumptions for the EV:

# %%
ELECTRICITY_CONSUMPTION = 0.2  # kWh/km
MILEAGE = 150_000  # km
LIFETIME = 15  # years

# Overall mass: 1200 kg
MASS_GLIDER = 840  # kg
MASS_POWERTRAIN = 80  # kg
MASS_BATTERY = 280  # kg

# %% [markdown]
# Based on these parameters, we create the following exchanges:

# %%
ev_lifecycle.new_edge(input=ev_lifecycle, amount=1, type="production").save() # production exchange

# %%
glider_production_exchange = ev_lifecycle.new_edge(
    input=glider_production, 
    amount=MASS_GLIDER, 
    type="technosphere"
)

powertrain_production_exchange = ev_lifecycle.new_edge(
    input=powertrain_production, 
    amount=MASS_POWERTRAIN, 
    type="technosphere"
)

battery_production_exchange = ev_lifecycle.new_edge(
    input=battery_production, 
    amount=MASS_BATTERY, 
    type="technosphere"
)

electricity_production_exchange = ev_lifecycle.new_edge(
    input=electricity_production,
    amount=ELECTRICITY_CONSUMPTION * MILEAGE,
    type="technosphere",
)

glider_eol_exchange = ev_lifecycle.new_edge(
    input=glider_eol,
    amount=MASS_GLIDER,  # amount not negative as its not modeled as a "true" waste process
    type="technosphere",
)

battery_eol_exchange = ev_lifecycle.new_edge(
    input=battery_eol, 
    amount=-MASS_BATTERY, 
    type="technosphere"
)

# %% [markdown]
# We need to add the temporal distributions at the exchanges level.
# See [BW_temporalis documentation](https://github.com/brightway-lca/bw_temporalis) for more information on `TemporalDistribution`. Timedelta, which we use below, describes relative temporal relations, e.g. 2 years earlier.

# %%
from bw_temporalis import TemporalDistribution, easy_timedelta_distribution
import numpy as np

# %%
td_production = easy_timedelta_distribution(
    start=-4,
    end=0,
    resolution="Y",     # "Y": "Years", "M": "Months", "D": "Days", "h": "Hours" etc.
    steps=5,
    kind="triangular", # available kinds: "triangular", "uniform", "normal"
    param=-1,
)

td_use_phase = easy_timedelta_distribution(
    start=0,  # (inclusive)
    end=LIFETIME,  # (inclusive)
    resolution="Y",
    steps=(LIFETIME + 1),  # Includes both start and end
    kind="uniform",  
)

td_eol = TemporalDistribution(
    date=np.array([LIFETIME + 1], dtype="timedelta64[Y]"), amount=np.array([1])  # if you build a TD manually, make sure that length of date array == length of amount array, and the sum of elements in the amount array == 1
)

# %% [markdown]
# Let's explore what a `TemporalDistribution` looks like:

# %%
print("td_production.date [s]:  ", td_production.date)
print("td_production.amount [%]:", td_production.amount)
type(td_production)
# Out:
# td_production.date [s]:   [-126227808  -94670856  -63113904  -31556952          0]
# td_production.amount [%]: [0.         0.16666667 0.33333333 0.5        0.        ]
# bw_temporalis.temporal_distribution.TemporalDistribution

# %% [markdown]
# We now add the temporal information to the inputs of our EV. We add temporal distributions to all exchanges, but you don't have to.

# %%
glider_production_exchange["temporal_distribution"] = td_production
glider_production_exchange.save()

powertrain_production_exchange["temporal_distribution"] = td_production
powertrain_production_exchange.save()

battery_production_exchange["temporal_distribution"] = td_production
battery_production_exchange.save()

electricity_production_exchange["temporal_distribution"] = td_use_phase
electricity_production_exchange.save()

glider_eol_exchange["temporal_distribution"] = td_eol
glider_eol_exchange.save()

battery_eol_exchange["temporal_distribution"] = td_eol
battery_eol_exchange.save()

# %% [markdown]
# ## LCA using `timex_lca`

# %% [markdown]
# As usual, we need to select a method:

# %%
method = ("EF v3.1", "climate change", "global warming potential (GWP100)")

# %% [markdown]
# `timex_lca` needs to know the representative time of the databases:

# %%
from datetime import datetime

database_date_dict = {
    "db_2020": datetime.strptime("2020", "%Y"),
    "db_2030": datetime.strptime("2030", "%Y"),
    "db_2040": datetime.strptime("2040", "%Y"),
    "foreground": "dynamic",  # flag databases that should be temporally distributed with "dynamic"
}

# %% [markdown]
# The inputs to `timex_lca` has a similar structure as `bw2calc.LCA`, with some additional arguments, including:
#
# `timex_lca`-related:
# - `database_date_dict`: representative time of background databases,
# - `temporal_grouping`: temporal resolution to which processes will be aggregated,"year" (default), "month", "day" or "hour"
# - `interpolation_type`: How the best fitting background database is selected: "linear"(default), "closest"
#
# but also optinal arguments for the graph traversal from `bw_temporalis`:
#
# - `cutoff`: stops graph traversal for nodes below this contribution to the static impact score.
# - `max_calc`: stops graph traversal if this number of nodes has been traversed
#
# Not sure about the required inputs? Check the documentation using `?`

# %%
from timex_lca import TimexLCA
TimexLCA?
# Out:
# Init signature:
# TimexLCA(
#     demand,
#     method,
#     database_date_dict: dict = None,
#     edge_filter_function: Callable = None,
#     temporal_grouping: str = 'year',
#     interpolation_type: str = 'linear',
#     *args,
#     **kwargs,
# )
# Docstring:
# Class to perform dynamic-prospective LCA calculations.
#
# The key point of TimexLCA is that it retrieves the LCI of processes occuring at a certain time from a database that represents the technology landscape at this point in time.
#
# It first calculates a static LCA, which informs a priority-first graph traversal, from which the temporal relationships between exchanges and processes are derived.
# For processes at the interface with background databases, the timing of the exchanges determines which background database to link to.
# This temporal relinking is achieved by using datapackages to add new processes, that represent processes happening at a specific time period, to the technopshere matrix
# and their corresponding biosphere flows to the biosphere matrix and then linking these to the original demand.
# The temporal information can also be used for dynamic LCIA chalculations.
#
# TimexLCA calculates:
#  1) a conventional LCA score (TimexLCA.static_lca.score(), same as BW2 lca.score()),
#  2) a dynamic-prospective LCA score, which links LCIs to the respective background databases but without additional temporal dynamics of the biosphere flows (TimexLCA.lca.score())
#  3) a dynamic-prospective LCA score with dynamic inventory and dynamic charaterization factors (not yet operational: TODO dynamic CFs in general and optional add Levasseur methodology with TH-cutoff)
# File:           ~/Documents/Coding/timex/timex_lca/timex_lca.py
# Type:           type
# Subclasses:

# %% [markdown]
# We calculate `timex_lca` for 1 EV life cycle:

# %%
tlca = TimexLCA({ev_lifecycle.key: 1}, method, database_date_dict, cutoff=1e-9)
# Out:
# /Users/timodiepers/Documents/Coding/timex/timex_lca/timex_lca.py:86: UserWarning: No edge filter function provided. Skipping all edges within background databases.
#   warnings.warn(
# Calculation count: 7

# %% [markdown]
# Next, we build a timeline of the exchanges, based on the results of the graph traversal. The exchanges are aggregated to the resolution specified in `temporal_grouping`.

# %%
tlca.build_timeline()
# Out:
#    date_producer                                      producer_name  \
# 0     2021-01-01                   market for glider, passenger car
# 1     2021-01-01  battery production, Li-ion, LiMn2O4, rechargea...
# 2     2021-01-01  market for powertrain, for electric passenger car
# 3     2022-01-01                   market for glider, passenger car
# 4     2022-01-01  battery production, Li-ion, LiMn2O4, rechargea...
# 5     2022-01-01  market for powertrain, for electric passenger car
# 6     2023-01-01                   market for glider, passenger car
# 7     2023-01-01  battery production, Li-ion, LiMn2O4, rechargea...
# 8     2023-01-01  market for powertrain, for electric passenger car
# 9     2024-01-01          market group for electricity, low voltage
# 10    2024-01-01                        Electric vehicle, lifecycle
# 11    2025-01-01          market group for electricity, low voltage
# 12    2026-01-01          market group for electricity, low voltage
# 13    2027-01-01          market group for electricity, low voltage
# 14    2028-01-01          market group for electricity, low voltage
# 15    2029-01-01          market group for electricity, low voltage
# 16    2030-01-01          market group for electricity, low voltage
# 17    2031-01-01          market group for electricity, low voltage
# 18    2032-01-01          market group for electricity, low voltage
# 19    2033-01-01          market group for electricity, low voltage
# 20    2034-01-01          market group for electricity, low voltage
# 21    2035-01-01          market group for electricity, low voltage
# 22    2036-01-01          market group for electricity, low voltage
# 23    2037-01-01          market group for electricity, low voltage
# 24    2038-01-01          market group for electricity, low voltage
# 25    2039-01-01          market group for electricity, low voltage
# 26    2040-01-01                     market for used Li-ion battery
# 27    2040-01-01  market for manual dismantling of used electric...
#
#    date_consumer                consumer_name     amount  \
# 0     2024-01-01  Electric vehicle, lifecycle      140.0
# 1     2024-01-01  Electric vehicle, lifecycle  46.666667
# 2     2024-01-01  Electric vehicle, lifecycle  13.333333
# 3     2024-01-01  Electric vehicle, lifecycle      280.0
# 4     2024-01-01  Electric vehicle, lifecycle  93.333333
# 5     2024-01-01  Electric vehicle, lifecycle  26.666667
# 6     2024-01-01  Electric vehicle, lifecycle      420.0
# 7     2024-01-01  Electric vehicle, lifecycle      140.0
# 8     2024-01-01  Electric vehicle, lifecycle       40.0
# 9     2024-01-01  Electric vehicle, lifecycle     1875.0
# 10    2024-01-01                           -1        1.0
# 11    2024-01-01  Electric vehicle, lifecycle     1875.0
# 12    2024-01-01  Electric vehicle, lifecycle     1875.0
# 13    2024-01-01  Electric vehicle, lifecycle     1875.0
# 14    2024-01-01  Electric vehicle, lifecycle     1875.0
# 15    2024-01-01  Electric vehicle, lifecycle     1875.0
# 16    2024-01-01  Electric vehicle, lifecycle     1875.0
# 17    2024-01-01  Electric vehicle, lifecycle     1875.0
# 18    2024-01-01  Electric vehicle, lifecycle     1875.0
# 19    2024-01-01  Electric vehicle, lifecycle     1875.0
# 20    2024-01-01  Electric vehicle, lifecycle     1875.0
# 21    2024-01-01  Electric vehicle, lifecycle     1875.0
# 22    2024-01-01  Electric vehicle, lifecycle     1875.0
# 23    2024-01-01  Electric vehicle, lifecycle     1875.0
# 24    2024-01-01  Electric vehicle, lifecycle     1875.0
# 25    2024-01-01  Electric vehicle, lifecycle     1875.0
# 26    2024-01-01  Electric vehicle, lifecycle     -280.0
# 27    2024-01-01  Electric vehicle, lifecycle      840.0
#
#                                 interpolation_weights
# 0   {'db_2020': 0.8998083766767041, 'db_2030': 0.1...
# 1   {'db_2020': 0.8998083766767041, 'db_2030': 0.1...
# 2   {'db_2020': 0.8998083766767041, 'db_2030': 0.1...
# 3   {'db_2020': 0.7998905009581166, 'db_2030': 0.2...
# 4   {'db_2020': 0.7998905009581166, 'db_2030': 0.2...
# 5   {'db_2020': 0.7998905009581166, 'db_2030': 0.2...
# 6   {'db_2020': 0.6999726252395291, 'db_2030': 0.3...
# 7   {'db_2020': 0.6999726252395291, 'db_2030': 0.3...
# 8   {'db_2020': 0.6999726252395291, 'db_2030': 0.3...
# 9   {'db_2020': 0.6000547495209416, 'db_2030': 0.3...
# 10                                               None
# 11  {'db_2020': 0.4998631261976457, 'db_2030': 0.5...
# 12  {'db_2020': 0.39994525047905827, 'db_2030': 0....
# 13  {'db_2020': 0.3000273747604708, 'db_2030': 0.6...
# 14  {'db_2020': 0.20010949904188335, 'db_2030': 0....
# 15  {'db_2020': 0.09991787571858746, 'db_2030': 0....
# 16                                     {'db_2030': 1}
# 17  {'db_2030': 0.9000547645125958, 'db_2040': 0.0...
# 18  {'db_2030': 0.8001095290251916, 'db_2040': 0.1...
# 19  {'db_2030': 0.6998904709748084, 'db_2040': 0.3...
# 20  {'db_2030': 0.5999452354874042, 'db_2040': 0.4...
# 21                   {'db_2030': 0.5, 'db_2040': 0.5}
# 22  {'db_2030': 0.4000547645125958, 'db_2040': 0.5...
# 23  {'db_2030': 0.29983570646221247, 'db_2040': 0....
# 24  {'db_2030': 0.19989047097480828, 'db_2040': 0....
# 25  {'db_2030': 0.0999452354874042, 'db_2040': 0.9...
# 26                                     {'db_2040': 1}
# 27                                     {'db_2040': 1}

# %% [markdown]
# The interpolation weights in the timeline (right most column above) specify the share of the amount of an exchange to be sourced from the respective database.
# `None` means that the exchange is in the foreground supply chain, and not at the intersection with the background system.

# %% [markdown]
# Next, we calculate the LCI.
#
# If we are only interested in the new overall time-explicit scores and don't care about the timing of the emissions, we can set `build_dynamic_biosphere`=`False`, which saves time and memory.

# %%
tlca.lci()

# %% [markdown]
# The static results without dynamic characterization:

# %%
tlca.static_lcia()
tlca.score   #kg CO2-eq
# Out:
# 16023.60243321808

# %% [markdown]
# ## Dynamic Characterization
# The time-explicit inventory generated by a `TimexLCA` allow for dynamic characterization. Users can provide their own dynamic characterization functions, or use the ones we provide out of the box. We provide two different metrics for dynamic LCIA of Climate Change: Radiative forcing [W/m2] and Global Warming Potential (GWP) [kg CO2-eq]. For both of these metrics, we have parameterized dynamic characterization functions for all GHG's that [IPCC AR6](https://www.ipcc.ch/report/ar6/wg1/chapter/chapter-7/) provides data for.
#
# For dynamic LCIA metrics, users can select the length of the considered time horizon (`time_horizon`) and whether it is a fixed time horizon (`fixed_time_horizon`). Fixed means that the time horizon for all emissions (no matter when they occur) starts counting at the time of the functional unit, resulting in shorter time horizons for emissions occuring later. If the time horizon is not fixed (this is what conventional impact assessment factors assume), it starts counting from the timing of the emission.

# %% [markdown]
# ### Radiative forcing

# %%
tlca.dynamic_lcia(metric="radiative_forcing", fixed_time_horizon=True)
# Out:
# /Users/timodiepers/Documents/Coding/timex/timex_lca/dynamic_characterization.py:44: UserWarning: No custom dynamic characterization functions provided. Using default dynamic characterization functions based on IPCC AR6 meant to work with biosphere3 flows. The flows that are characterized are based on the selection of the initially chosen impact category: ('EF v3.1', 'climate change', 'global warming potential (GWP100)'). You can look up the mapping in the timex_lca.dynamic_characterizer.characterization_function_dict.
#   warnings.warn(
#                       date        amount  flow  \
# 0      2022-01-01 05:49:12  1.678511e-18  1617
# 152    2022-01-01 05:49:12  8.889330e-24   430
# 153    2022-01-01 05:49:12  2.824307e-17  3630
# 154    2022-01-01 05:49:12  3.062504e-19  1613
# 155    2022-01-01 05:49:12  1.087367e-18  1612
# ...                    ...           ...   ...
# 140843 2123-01-01 20:31:12  2.229446e-36  1373
# 140844 2123-01-01 20:31:12 -2.330110e-19  3636
# 140845 2123-01-01 20:31:12  2.603391e-15  3642
# 140834 2123-01-01 20:31:12  1.481609e-29  1331
# 140873 2123-01-01 20:31:12  4.441310e-17   255
#
#                                          flow_name  activity  \
# 0             Methane, bromotrifluoro-, Halon 1301     41508
# 152           Methane, bromotrifluoro-, Halon 1301     27559
# 153            Methane, from soil or biomass stock     27559
# 154      Methane, bromochlorodifluoro-, Halon 1211     41508
# 155                    Methane, bromo-, Halon 1001     27559
# ...                                            ...       ...
# 140843               Ethane, pentafluoro-, HFC-125     50069
# 140844    Carbon dioxide, to soil or biomass stock     50069
# 140845  Carbon dioxide, from soil or biomass stock     50069
# 140834          Ethane, 1,1,1-trichloro-, HCFC-140     50069
# 140873                Ethane, hexafluoro-, HFC-116     50069
#
#                                       activity_name    amount_sum
# 0       (db_2020, ba87aff6361d99be2636e8c59e55a5b2)  1.678511e-18
# 152     (db_2020, 133b33cc867081af144475d62179286b)  1.560818e-12
# 153     (db_2020, 133b33cc867081af144475d62179286b)  1.560846e-12
# 154     (db_2020, ba87aff6361d99be2636e8c59e55a5b2)  1.560847e-12
# 155     (db_2020, 133b33cc867081af144475d62179286b)  1.560848e-12
# ...                                             ...           ...
# 140843  (db_2020, fec93a95a9a84d7fa0ede9c3082bb79f)  1.380266e-09
# 140844  (db_2020, fec93a95a9a84d7fa0ede9c3082bb79f)  1.380266e-09
# 140845  (db_2020, fec93a95a9a84d7fa0ede9c3082bb79f)  1.380269e-09
# 140834  (db_2020, fec93a95a9a84d7fa0ede9c3082bb79f)  1.380244e-09
# 140873  (db_2020, fec93a95a9a84d7fa0ede9c3082bb79f)  1.380377e-09
#
# [140874 rows x 7 columns]

# %%
tlca.dynamic_score #W/m2 (radiative forcing)
# Out:
# 1.3803773184379228e-09

# %% [markdown]
# We can check the dynamic characterization functions used:

# %%
tlca.dynamic_characterizer.characterization_function_dict
# Out:
# {3856: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1145: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1146: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1144: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1147: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  96: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1169: <function timex_lca.dynamic_characterization.characterize_co2(series, period: int | None = 100, cumulative: bool | None = False) -> pandas.core.frame.DataFrame>,
#  1170: <function timex_lca.dynamic_characterization.characterize_co2(series, period: int | None = 100, cumulative: bool | None = False) -> pandas.core.frame.DataFrame>,
#  1168: <function timex_lca.dynamic_characterization.characterize_co2(series, period: int | None = 100, cumulative: bool | None = False) -> pandas.core.frame.DataFrame>,
#  1171: <function timex_lca.dynamic_characterization.characterize_co2(series, period: int | None = 100, cumulative: bool | None = False) -> pandas.core.frame.DataFrame>,
#  112: <function timex_lca.dynamic_characterization.characterize_co2(series, period: int | None = 100, cumulative: bool | None = False) -> pandas.core.frame.DataFrame>,
#  3635: <function timex_lca.dynamic_characterization.characterize_co2(series, period: int | None = 100, cumulative: bool | None = False) -> pandas.core.frame.DataFrame>,
#  3640: <function timex_lca.dynamic_characterization.characterize_co2(series, period: int | None = 100, cumulative: bool | None = False) -> pandas.core.frame.DataFrame>,
#  3642: <function timex_lca.dynamic_characterization.characterize_co2(series, period: int | None = 100, cumulative: bool | None = False) -> pandas.core.frame.DataFrame>,
#  3632: <function timex_lca.dynamic_characterization.characterize_co2(series, period: int | None = 100, cumulative: bool | None = False) -> pandas.core.frame.DataFrame>,
#  3643: <function timex_lca.dynamic_characterization.characterize_co2(series, period: int | None = 100, cumulative: bool | None = False) -> pandas.core.frame.DataFrame>,
#  3717: <function timex_lca.dynamic_characterization.characterize_co2_uptake(series, period: int | None = 100, cumulative: bool | None = False) -> pandas.core.frame.DataFrame>,
#  3745: <function timex_lca.dynamic_characterization.characterize_co2_uptake(series, period: int | None = 100, cumulative: bool | None = False) -> pandas.core.frame.DataFrame>,
#  3719: <function timex_lca.dynamic_characterization.characterize_co2_uptake(series, period: int | None = 100, cumulative: bool | None = False) -> pandas.core.frame.DataFrame>,
#  3636: <function timex_lca.dynamic_characterization.characterize_co2_uptake(series, period: int | None = 100, cumulative: bool | None = False) -> pandas.core.frame.DataFrame>,
#  1209: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1210: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1208: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1211: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  137: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  4686: <function timex_lca.dynamic_characterization.characterize_n2o(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  4687: <function timex_lca.dynamic_characterization.characterize_n2o(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  4685: <function timex_lca.dynamic_characterization.characterize_n2o(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  4688: <function timex_lca.dynamic_characterization.characterize_n2o(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  4684: <function timex_lca.dynamic_characterization.characterize_n2o(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1317: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1318: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1316: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1319: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  241: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1325: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1326: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1324: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1327: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  243: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1329: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1330: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1328: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1331: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  244: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1333: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1334: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1332: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1335: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  245: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1340: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  4262: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  4263: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  4261: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  4269: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1342: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1343: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1341: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1344: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  247: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1346: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1347: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1345: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1348: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  248: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1350: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1351: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1349: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1352: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  249: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  4259: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  4258: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  4260: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  4257: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  4268: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1354: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1355: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1353: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1356: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  250: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1358: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1359: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1357: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1360: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  251: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1362: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1363: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1361: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1364: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  252: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1366: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1367: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1365: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1368: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  253: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1370: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1371: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1369: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1372: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  255: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1374: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1375: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1373: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1376: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  256: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1610: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1611: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1609: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1612: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  428: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1614: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1615: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1613: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1616: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  429: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1618: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1619: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1617: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1620: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  430: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1627: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1625: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1628: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  432: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1622: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1623: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1621: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1624: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  431: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1630: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1631: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1629: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1632: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  433: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1634: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1635: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1633: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1636: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  434: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1638: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1639: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1637: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1640: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  435: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1642: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1643: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1641: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1644: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  436: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1646: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1647: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1645: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1648: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  437: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1650: <function timex_lca.dynamic_characterization.characterize_ch4(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1651: <function timex_lca.dynamic_characterization.characterize_ch4(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1649: <function timex_lca.dynamic_characterization.characterize_ch4(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1652: <function timex_lca.dynamic_characterization.characterize_ch4(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  438: <function timex_lca.dynamic_characterization.characterize_ch4(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  3631: <function timex_lca.dynamic_characterization.characterize_ch4(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  3633: <function timex_lca.dynamic_characterization.characterize_ch4(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  3630: <function timex_lca.dynamic_characterization.characterize_ch4(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  3637: <function timex_lca.dynamic_characterization.characterize_ch4(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  3644: <function timex_lca.dynamic_characterization.characterize_ch4(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1654: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1655: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1653: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1656: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  439: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1658: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1659: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1657: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1660: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  441: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1662: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1663: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1661: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1664: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  442: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1666: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1667: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1665: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1668: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  443: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1670: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1671: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1669: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1672: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  444: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1714: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1712: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1715: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  470: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1749: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1750: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1748: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1751: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  494: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1861: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1862: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1860: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1863: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  622: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1997: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1998: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1996: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1999: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  717: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1389: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1390: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1388: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1391: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  260: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1393: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1394: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  1392: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  3835: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#  261: <function timex_lca.dynamic_characterization.create_generic_characterization_function.<locals>.characterize_generic(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>}

# %%
#the keys in the dictionary above are the ids of the biosphere flows
print(bd.get_node(id= 1169))
tlca.dynamic_characterizer.characterization_function_dict[1169]
# Out:
# 'Carbon dioxide, fossil' (kilogram, None, ('air', 'low population density, long-term'))
# <function timex_lca.dynamic_characterization.characterize_co2(series, period: int | None = 100, cumulative: bool | None = False) -> pandas.core.frame.DataFrame>

# %% [markdown]
# Simple plotting functions are available:

# %%
tlca.plot_dynamic_characterized_inventory(sum_emissions_within_activity=True)

# %% [markdown]
# Without summing up the emissions within the activity, one can see that there are also negative emissions in the system, which stem from the premise-induced BECCS in the future electricity production:

# %%
tlca.plot_dynamic_characterized_inventory()

# %% [markdown]
# Cumulative radiative forcing:

# %%
tlca.plot_dynamic_characterized_inventory(sum_activities= True, cumsum=True)

# %% [markdown]
# ### GWP

# %% [markdown]
# Similar options are available for the metric GWP, which compares the radiative forcing of a GHG to that of CO2 over a certain time horizon (commonly 100 years, but it can be set flexibly in `time_horizon`).

# %%
tlca.dynamic_lcia(metric="GWP", fixed_time_horizon=False, time_horizon = 70)
tlca.dynamic_score #kg CO2-eq (GWP)
# Out:
# /Users/timodiepers/Documents/Coding/timex/timex_lca/dynamic_characterization.py:44: UserWarning: No custom dynamic characterization functions provided. Using default dynamic characterization functions based on IPCC AR6 meant to work with biosphere3 flows. The flows that are characterized are based on the selection of the initially chosen impact category: ('EF v3.1', 'climate change', 'global warming potential (GWP100)'). You can look up the mapping in the timex_lca.dynamic_characterizer.characterization_function_dict.
#   warnings.warn(
# /Users/timodiepers/Documents/Coding/timex/timex_lca/dynamic_characterization.py:88: UserWarning: Using timex_lca's default co2 characterization function for GWP reference.
#   warnings.warn(
# 16226.568001917642

# %% [markdown]
# Plotting the GWP results over time:

# %%
tlca.plot_dynamic_characterized_inventory()

# %% [markdown]
# Cumulative:

# %%
tlca.plot_dynamic_characterized_inventory(sum_emissions_within_activity=True, cumsum=True)

# %% [markdown]
# ### Comparison of time-explicit results to static results
# It's helpful to understand how the time-explicit results differ from those using static assessments.
#
# We compare the time-explicit results with those of an LCA for the year 2020 and 2040 for the standard GWP100 metric (time horizon=100 and no fixed time horizon). This means we neglect the additional differences of the time-explicit results that would arise from using dynamic LCIA.

# %% [markdown]
# Time-explicit scores:

# %%
tlca.dynamic_lcia(metric="GWP", fixed_time_horizon=False, time_horizon=100)
tlca.dynamic_score
# Out:
# /Users/timodiepers/Documents/Coding/timex/timex_lca/dynamic_characterization.py:44: UserWarning: No custom dynamic characterization functions provided. Using default dynamic characterization functions based on IPCC AR6 meant to work with biosphere3 flows. The flows that are characterized are based on the selection of the initially chosen impact category: ('EF v3.1', 'climate change', 'global warming potential (GWP100)'). You can look up the mapping in the timex_lca.dynamic_characterizer.characterization_function_dict.
#   warnings.warn(
# /Users/timodiepers/Documents/Coding/timex/timex_lca/dynamic_characterization.py:88: UserWarning: Using timex_lca's default co2 characterization function for GWP reference.
#   warnings.warn(
# 15769.83058207004

# %% [markdown]
# Calculation of 2020 (static) scores:

# %%
import bw2calc as bc

static_scores = {}
for e in ev_lifecycle.exchanges():
    if e.input == ev_lifecycle.key:
        continue
    lca = bc.LCA({e.input: e.amount}, method)
    lca.lci()
    lca.lcia()
    static_scores[e.input["name"]] = lca.score

# %% [markdown]
# Calculation of 2040 (prospective) scores:

# %%
#first create a copy of the system and relink to processes from 2040 database
prospective_ev_lifecycle = ev_lifecycle.copy()

for exc in prospective_ev_lifecycle.exchanges():
    if exc.input == prospective_ev_lifecycle:
        continue
    exc.input = bd.get_node(
        **{
            "database": "db_2040",
            "name": exc.input["name"],
            "product": exc.input["reference product"],
            "location": exc.input["location"],
        }
    )
    exc.save()

prospective_scores = {}
for e in prospective_ev_lifecycle.exchanges():
    if e.input == prospective_ev_lifecycle.key:
        continue
    lca = bc.LCA({e.input: e.amount}, method)
    lca.lci()
    lca.lcia()
    prospective_scores[e.input["name"]] = lca.score

# %% [markdown]
# Lets compare the overall scores:

# %%
print("Static score: ", sum(static_scores.values()))
print("Prospective score: ", sum(prospective_scores.values()))
print("Time-explicit score: ", tlca.dynamic_score)
# Out:
# Static score:  31401.500710765587
# Prospective score:  7234.099282744538
# Time-explicit score:  15769.83058207004

# %% [markdown]
# To better understand what's going on, let's plot the scores as a waterfall chart  based on timing of emission:

# %%
from timex_lca.utils import plot_characterized_inventory_as_waterfall

order_stacked_activities = (
    [  # to sort stacked bars in waterfall plot chronologically from production to EoL
        "market for glider, passenger car",
        "market for powertrain, for electric passenger car",
        "battery production, Li-ion, LiMn2O4, rechargeable, prismatic",
        "market group for electricity, low voltage",
        "market for manual dismantling of used electric passenger car",
        "market for used Li-ion battery",
    ]
)

plot_characterized_inventory_as_waterfall(
    tlca.characterized_inventory,
    metric=tlca.metric,
    static_scores=static_scores,
    prospective_scores=prospective_scores,
    order_stacked_activities=order_stacked_activities,
)

# %% [markdown]
# One can see that the time-explicit results (in the middle) are somewhere in between the static and the prospective results. This makes sense as at each timestep, the underlying processes are sourced from progressively "cleaner" background databases, reaching a lower impact than if they are only sourced from the current database, but not so low as the prospective results, which are fully sourced from the most decarbonized database. Notably, the electricity consumption in the use-phase, modelled uniformly over the lifetime of the EV, contributes less and less to the score in the later years, since the electricity becomes cleaner in the future databases.
