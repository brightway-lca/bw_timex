# %% [markdown]
# # Time-explicit LCA of an electric vehicle
#
# annotated for Dds LCA-MFA Autumn School 2025

# %% [markdown]
# This notebook shows how to use `bw_timex` with a cradle-to-grave case study of an electric vehicle (ev). The case study is simplified, not meant to reflect the complexity of electric mobility but to demonstrate how to use `bw_timex`.
#
# > **Note:** This is the "standalone" version of this notebook with some made up background processes, but there is also a version available that works with [ecoinvent and premise databases](https://github.com/brightway-lca/bw_timex/blob/main/notebooks/example_electric_vehicle_premise.ipynb).
#
# > **Note:** It is a slightly modified version with additional explanations compared to the [original standalone notebook](https://github.com/brightway-lca/bw_timex/blob/main/notebooks/example_electric_vehicle_standalone.ipynb)

# %% [markdown]
# ## Prospective background databases
#
# The `bw_timex` package itself does not provide any data - specifying prospective and dynamic information is up to the user. To make this notebook executable for anyone, anywhere, and not rely on any external data, we make up three different background databases for this example, representing the years 2020, 2030 and 2040. Also, we create a very simple biosphere database.

# %%
import bw2data as bd

bd.projects.set_current("electric_vehicle_standalone")

# making sure to start fresh
for db in list(bd.databases):
    del bd.databases[db]

# %%
biosphere = bd.Database("biosphere")
biosphere.write(
    {
        ("biosphere", "CO2"): {
            "type": "emission",
            "name": "carbon dioxide",
        },
    }
)

background_2020 = bd.Database("background_2020")
background_2030 = bd.Database("background_2030")
background_2040 = bd.Database("background_2040")

background_2020.write({})
background_2030.write({})
background_2040.write({})

background_databases = [
    background_2020,
    background_2030,
    background_2040,
]
# Out:
# 100%|██████████| 1/1 [00:00<?, ?it/s]
# Vacuuming database

# %% [markdown]
# We now create some very simple processes within these databases. These process get only one aggregated CO2-emission each. The amounts of these emissions change over time.

# %%
process_co2_emissions = {
    "glider": (10, 5, 2.5), # for 2020, 2030 and 2040
    "powertrain": (20, 10, 7.5),
    "battery": (10, 5, 4),
    "electricity": (0.5, 0.25, 0.075),
    "glider_eol": (0.01, 0.0075, 0.005),
    "powertrain_eol": (0.01, 0.0075, 0.005),
    "battery_eol": (1, 0.5, 0.25),
}

node_co2 = biosphere.get("CO2")

for component_name, gwis in process_co2_emissions.items():
    for database, gwi in zip(background_databases, gwis):
        database.new_node(component_name, name=component_name, location="somewhere").save()
        component = database.get(component_name)
        component["reference product"] = component_name        
        component.save()
        production_amount = -1 if "eol" in component_name else 1
        component.new_edge(input=component, amount=production_amount, type="production").save()
        component.new_edge(input=node_co2, amount=gwi, type="biosphere").save()

# %% [markdown]
# ## Case study setup

# %% [markdown]
# In this study, we consider the following production system for our ev. Purple boxes are foreground, cyan boxes are background (i.e., ecoinvent/premise/made-up in our case).

# %% [markdown]
# ```mermaid
# flowchart LR
#     glider_production(glider production):::ei-->ev_production
#     powertrain_production(powertrain production):::ei-->ev_production
#     battery_production(battery production):::ei-->ev_production
#     ev_production(ev production):::fg-->driving
#     electricity_generation(electricity generation):::ei-->driving
#     driving(driving):::fg-->used_ev
#     used_ev(used ev):::fg-->glider_eol(glider eol):::ei
#     used_ev-->powertrain_eol(powertrain eol):::ei
#     used_ev-->battery_eol(battery eol):::ei
#
#     classDef ei color:#222832, fill:#3fb1c5, stroke:none;
#     classDef fg color:#222832, fill:#9c5ffd, stroke:none;
# ```

# %% [markdown]
# ### Modeling the production system
#
# Now, we need to build this with brightway. If you are not interested in the modeling details, feel free to skip this section.
#
# For our ev model we make the following assumptions:

# %%
ELECTRICITY_CONSUMPTION = 0.2 # kWh/km
MILEAGE = 150_000 # km
LIFETIME = 15 # years

# Overall mass: 1200 kg
MASS_GLIDER = 840 # kg
MASS_POWERTRAIN = 80 # kg
MASS_BATTERY = 280 # kg

# %% [markdown]
# First, we create a new foreground database:

# %%
if "foreground" in bd.databases:
    del bd.databases["foreground"] # to make sure we create the foreground from scratch
foreground = bd.Database("foreground")
foreground.register()

# %% [markdown]
# Now, let's create the foreground activities:

# %%
ev_production = foreground.new_node("ev_production", name="production of an electric vehicle", unit="unit")
ev_production['reference product'] = "electric vehicle"
ev_production.save()
ev_production.new_edge(input=ev_production, amount=1, type="production").save()

driving = foreground.new_node("driving", name="driving an electric vehicle", unit="transport over an ev lifetime")
driving['reference product'] = "transport"
driving.save()
driving.new_edge(input=driving, amount=1, type="production").save()

used_ev = foreground.new_node("used_ev", name="used electric vehicle", unit="unit")
used_ev['reference product'] = "used electric vehicle"
used_ev.save()
used_ev.new_edge(input=used_ev, amount=-1, type="production").save()  # -1 as this gets rid of a used car

# %% [markdown]
# Now, let's build the exchanges, starting with the ev production:

# %%
glider_production = background_2020.get(code="glider")
powertrain_production = background_2020.get(code="powertrain")
battery_production = background_2020.get(code="battery")

glider_to_ev = ev_production.new_edge(
    input=glider_production,
    amount=MASS_GLIDER, 
    type="technosphere"
)
powertrain_to_ev = ev_production.new_edge(
    input=powertrain_production, 
    amount=MASS_POWERTRAIN, 
    type="technosphere"
)
battery_to_ev = ev_production.new_edge(
    input=battery_production, 
    amount=MASS_BATTERY, 
    type="technosphere"
)

# %% [markdown]
# ... the end of life:

# %%
glider_eol = background_2020.get(name="glider_eol")
powertrain_eol = background_2020.get(name="powertrain_eol")
battery_eol = background_2020.get(name="battery_eol")

used_ev_to_glider_eol = used_ev.new_edge(
    input=glider_eol,
    amount=-MASS_GLIDER,
    type="technosphere",
)
used_ev_to_powertrain_eol = used_ev.new_edge(
    input=powertrain_eol,
    amount=-MASS_POWERTRAIN,
    type="technosphere",
)
used_ev_to_battery_eol = used_ev.new_edge(
    input=battery_eol,
    amount=-MASS_BATTERY,
    type="technosphere",
)

# %% [markdown]
# ...and, finally, driving:

# %%
electricity_production = background_2020.get(name="electricity")

driving_to_used_ev = driving.new_edge(input=used_ev, amount=-1, type="technosphere")

ev_to_driving = driving.new_edge(
    input=ev_production, 
    amount=1, 
    type="technosphere"
)
electricity_to_driving = driving.new_edge(
    input=electricity_production,
    amount=ELECTRICITY_CONSUMPTION * MILEAGE,
    type="technosphere",
)

# %% [markdown]
# ### Adding temporal information
#
# Now that the production system is modelled, we can add temporal distributions at the exchange level. The temporal information we want to embed in our product system looks somewhat like this:
#
# ```mermaid
# flowchart LR
#     glider_production(glider production):::ei-->|0-2 years prior|ev_production
#     powertrain_production(powertrain production):::ei-->|1 year prior|ev_production
#     battery_production(battery production):::ei-->|1 year prior|ev_production
#     ev_production(ev production):::fg-->|0-3 months prior|driving
#     electricity_generation(electricity generation):::ei-->|uniformly distributed<br/> over lifetime|driving
#     driving(driving):::fg-->|after ev lifetime|used_ev
#     used_ev(used ev):::fg-->|3 months after <br/> ev lifetime|glider_eol(glider eol):::ei
#     used_ev-->|3 months after <br/> ev lifetime|powertrain_eol(powertrain eol):::ei
#     used_ev-->|3 months after <br/> ev lifetime|battery_eol(battery eol):::ei
#
#     classDef ei color:#222832, fill:#3fb1c5, stroke:none;
#     classDef fg color:#222832, fill:#9c5ffd, stroke:none;
# ```
#
# To include this temopral information, we use the `TemporalDistribution` class from `bw_temporalis`. For more info, take a look at the [bw_temporalis documentation](https://github.com/brightway-lca/bw_temporalis).
#
# Notably, in addition to the timestamp of the occurence of the process (which is shown in the flowchart above), we also need to specify the amount share of the exchange that happens at that time to fully define a `TemporalDistribution`.

# %%
from bw_temporalis import TemporalDistribution, easy_timedelta_distribution
import numpy as np

td_assembly_and_delivery = TemporalDistribution(
    date=np.array([-3, -2], dtype="timedelta64[M]"), amount=np.array([0.2, 0.8])
)

td_glider_production = TemporalDistribution(
    date=np.array([-2, -1, 0], dtype="timedelta64[Y]"), amount=np.array([0.7, 0.1, 0.2])
)

td_produce_powertrain_and_battery = TemporalDistribution(
    date=np.array([-1], dtype="timedelta64[Y]"), amount=np.array([1])
)

td_use_phase = easy_timedelta_distribution(
    start=0,
    end=LIFETIME,
    resolution="Y",
    steps=(LIFETIME + 1),
    kind="uniform", # you can also do "normal" or "triangular" distributions
)

td_disassemble_used_ev = TemporalDistribution(
    date=np.array([LIFETIME + 1], dtype="timedelta64[Y]"), amount=np.array([1])
)

td_treating_waste = TemporalDistribution(
    date=np.array([3], dtype="timedelta64[M]"), amount=np.array([1])
)

# %% [markdown]
# `bw_timex` "adds" (the mathematical correct term is convolution) the `Temporal_Distributions` of individual processes in the supply chain when building the timeline. We will explore this below, as it is easier to understand when looking at the final product (the timeline)

# %% [markdown]
# We now add the temporal information to the exchanges of our EV. We add temporal distributions to all (technosphere) exchanges, but you don't have to.

# %%
glider_to_ev["temporal_distribution"] = td_glider_production
glider_to_ev.save()

powertrain_to_ev["temporal_distribution"] = td_produce_powertrain_and_battery
powertrain_to_ev.save()

battery_to_ev["temporal_distribution"] = td_produce_powertrain_and_battery
battery_to_ev.save()

ev_to_driving["temporal_distribution"] = td_assembly_and_delivery
ev_to_driving.save()

electricity_to_driving["temporal_distribution"] = td_use_phase
electricity_to_driving.save()

driving_to_used_ev["temporal_distribution"] = td_disassemble_used_ev
driving_to_used_ev.save()

used_ev_to_glider_eol["temporal_distribution"] = td_treating_waste
used_ev_to_glider_eol.save()

used_ev_to_powertrain_eol["temporal_distribution"] = td_treating_waste
used_ev_to_powertrain_eol.save()

used_ev_to_battery_eol["temporal_distribution"] = td_treating_waste
used_ev_to_battery_eol.save()

# %% [markdown]
# ### Add a characterization method

# %% [markdown]
# Finally, we need some characterization method. Again, this is just a simple made-up one:

# %%
bd.Method(("GWP", "example")).write(
    [
        (("biosphere", "CO2"), 1),
    ]
)

# %% [markdown]
# ## LCA using `bw_timex`

# %% [markdown]
# #### Initialization

# %% [markdown]
# Now that the data is set up, we can get startet with the actual time-explicit LCA. As usual, we need to select a method first:

# %%
method = ("GWP", "example")

# %% [markdown]
# `bw_timex` needs to know the representative time of the databases:

# %%
from datetime import datetime

database_dates = {
    background_2020.name: datetime.strptime("2020", "%Y"),
    background_2030.name: datetime.strptime("2030", "%Y"),
    background_2040.name: datetime.strptime("2040", "%Y"),
    "foreground": "dynamic",  # flag databases that should be temporally distributed with "dynamic"
}

# %% [markdown]
# Now, we can instantiate a `TimexLCA`. It's structure is similar to a normal `bw2calc.LCA`, but with the additional argument `database_dates`.
#
# Not sure about the required inputs? Check the documentation using `?`. All our classes and methods have docstrings!

# %%
from bw_timex import TimexLCA
TimexLCA?
# Out:
# Init signature: TimexLCA(demand: dict, method: tuple, database_dates: dict = None) -> None
# Docstring:
# Class to perform time-explicit LCA calculations.
#
# A TimexLCA contains the LCI of processes occurring at explicit points in time. It tracks the timing of processes,
# relinks their technosphere and biosphere exchanges to match the technology landscape at that point in time,
# and also keeps track of the timing of the resulting emissions. As such, it combines prospective and dynamic LCA
# approaches.
#
# TimexLCA first calculates a static LCA, which informs a priority-first graph traversal. From the
# graph traversal, temporal relationships between exchanges and processes are derived. Based on
# the timing of the processes, bw_timex matches the processes at the intersection between
# foreground and background to the best available background databases. This temporal relinking is
# achieved by using datapackages to add new time-specific processes. The new processes and their
# exchanges to other technosphere processes or biosphere flows extent the technosphere and
# biosphere matrices.
#
# Temporal information of both processes and biosphere flows is retained, allowing for dynamic
# LCIA.
#
# TimexLCA calculates:
#  1) a static "base" LCA score (`TimexLCA.base_score`, same as `bw2calc.lca.score`),
#  2) a static time-explicit LCA score (`TimexLCA.static_score`), which links LCIs to the
#     respective background databases, but without dynamic characterization of the time-explicit inventory
#  3) a dynamic time-explicit LCA score (`TimexLCA.dynamic_score`), with dynamic inventory and
#     dynamic characterization. These are provided for radiative forcing and GWP but can also be
#     user-defined.
#
#
# Example
# -------
# >>> demand = {('my_foreground_database', 'my_process'): 1}
# >>> method = ("some_method_family", "some_category", "some_method")
# >>> database_dates = {
#         'my_background_database_one': datetime.strptime("2020", "%Y"),
#         'my_background_database_two': datetime.strptime("2030", "%Y"),
#         'my_background_database_three': datetime.strptime("2040", "%Y"),
#         'my_foreground_database':'dynamic'
#     }
# >>> tlca = TimexLCA(demand, method, database_dates)
# >>> tlca.build_timeline() # has many optional arguments
# >>> tlca.lci()
# >>> tlca.static_lcia()
# >>> print(tlca.static_score)
# >>> tlca.dynamic_lcia(metric="radiative_forcing") # also available: "GWP"
# >>> print(tlca.dynamic_score)
# Init docstring:
# Instantiating a `TimexLCA` object calculates a static LCA, initializes time mappings
# for activities and biosphere flows, and stores useful subsets of ids in the
# node_collections.
#
# Parameters
# ----------
# demand : dict[object: float]
#         The demand for which the LCA will be calculated. The keys can be Brightway `Node`
#         instances, `(database, code)` tuples, or integer ids.
# method : tuple
#         Tuple defining the LCIA method, such as `('foo', 'bar')` or default methods, such as
#         `("EF v3.1", "climate change", "global warming potential (GWP100)")`
# database_dates : dict, optional
#         Dictionary mapping database names to dates.
# File:           c:\users\mullera\onedrive - vito\documents\04_coding\tictac_lca\bw_timex\timex_lca.py
# Type:           type
# Subclasses:

# %% [markdown]
# Let's create a `TimexLCA` object for our EV life cycle:

# %%
tlca = TimexLCA({driving: 1}, method, database_dates)
# Out:
# 2025-11-11 13:29:42.347 | INFO     | bw_timex.timex_lca:__init__:114 - Initializing TimexLCA object...
# 2025-11-11 13:29:42.349 | INFO     | bw_timex.timex_lca:__init__:136 - Collecting node infos...

# %% [markdown]
# Next, we build a timeline of the exchanges. To do this, we can call the `build_timeline()` method, which does the graph traversal and creates a timeline dataframe from the results. The exchanges (rows of the dataframe) are aggregated to the resolution specified in the argument `temporal_grouping`. There are also many more options to specify the timeline creation and graph traversal process. Here are the most important ones:
# - `temporal_grouping`: temporal resolution to which processes will be aggregated,"year" (default), "month", "day" or "hour"
# - `interpolation_type`: How the best fitting background database is selected: "linear"(default), "closest"
# - `edge_filter_function`: Custom filter function specifying when to stop the graph traversal.
# - `cutoff`: stops graph traversal for nodes below this contribution to the static impact score.
# - `max_calc`: stops graph traversal if this number of nodes has been traversed
#
# For all these options, we provide sensible default values. Of course you can always just check the docstrings to see all your options and our assumptions for default values.

# %% [markdown]
# #### Timeline
#
# So, let's build the timeline. We choose a monthly temporal grouping here because we use that resolution in our temporal distributions.

# %%
timeline = tlca.build_timeline(starting_datetime = "2025-11-01", temporal_grouping="month")
# Out:
# 2025-11-11 13:29:42.411 | INFO     | bw_timex.timex_lca:build_timeline:216 - No edge filter function provided. Skipping all edges in background databases.
# 2025-11-11 13:29:42.415 | INFO     | bw_timex.timex_lca:build_timeline:232 - Calculating base LCA...
# 2025-11-11 13:29:43.125 | INFO     | bw_timex.timex_lca:build_timeline:242 - Creating activity time mapping...
# 2025-11-11 13:29:43.125 | INFO     | bw_timex.timeline_builder:__init__:99 - Traversing supply chain graph...
# 2025-11-11 13:29:43.161 | INFO     | bw_timex.timeline_builder:build_timeline:142 - Building timeline...
# 2025-11-11 13:29:43.205 | INFO     | bw_timex.timeline_builder:get_weights_for_interpolation_between_nearest_years:528 - Reference date 2040-11-01 00:00:00 is higher than all provided dates. Data will be taken from the closest lower year.
# 2025-11-11 13:29:43.207 | INFO     | bw_timex.timeline_builder:get_weights_for_interpolation_between_nearest_years:528 - Reference date 2041-11-01 00:00:00 is higher than all provided dates. Data will be taken from the closest lower year.
# 2025-11-11 13:29:43.207 | INFO     | bw_timex.timeline_builder:get_weights_for_interpolation_between_nearest_years:528 - Reference date 2042-02-01 00:00:00 is higher than all provided dates. Data will be taken from the closest lower year.
# 2025-11-11 13:29:43.207 | INFO     | bw_timex.timeline_builder:get_weights_for_interpolation_between_nearest_years:528 - Reference date 2042-02-01 00:00:00 is higher than all provided dates. Data will be taken from the closest lower year.
# 2025-11-11 13:29:43.207 | INFO     | bw_timex.timeline_builder:get_weights_for_interpolation_between_nearest_years:528 - Reference date 2042-02-01 00:00:00 is higher than all provided dates. Data will be taken from the closest lower year.
# Starting graph traversal
# Calculation count: 9

# %%
timeline
# Out:
#    date_producer                      producer_name date_consumer  \
# 0     2023-08-01                             glider    2025-08-01
# 1     2023-09-01                             glider    2025-09-01
# 2     2024-08-01                             glider    2025-08-01
# 3     2024-08-01                         powertrain    2025-08-01
# 4     2024-08-01                            battery    2025-08-01
# 5     2024-09-01                             glider    2025-09-01
# 6     2024-09-01                         powertrain    2025-09-01
# 7     2024-09-01                            battery    2025-09-01
# 8     2025-08-01                             glider    2025-08-01
# 9     2025-08-01  production of an electric vehicle    2025-11-01
# 10    2025-09-01                             glider    2025-09-01
# 11    2025-09-01  production of an electric vehicle    2025-11-01
# 12    2025-11-01                        electricity    2025-11-01
# 13    2025-11-01        driving an electric vehicle    2025-11-01
# 14    2026-11-01                        electricity    2025-11-01
# 15    2027-11-01                        electricity    2025-11-01
# 16    2028-11-01                        electricity    2025-11-01
# 17    2029-11-01                        electricity    2025-11-01
# 18    2030-11-01                        electricity    2025-11-01
# 19    2031-11-01                        electricity    2025-11-01
# 20    2032-11-01                        electricity    2025-11-01
# 21    2033-11-01                        electricity    2025-11-01
# 22    2034-11-01                        electricity    2025-11-01
# 23    2035-11-01                        electricity    2025-11-01
# 24    2036-11-01                        electricity    2025-11-01
# 25    2037-11-01                        electricity    2025-11-01
# 26    2038-11-01                        electricity    2025-11-01
# 27    2039-11-01                        electricity    2025-11-01
# 28    2040-11-01                        electricity    2025-11-01
# 29    2041-11-01              used electric vehicle    2025-11-01
# 30    2042-02-01                         glider_eol    2041-11-01
# 31    2042-02-01                     powertrain_eol    2041-11-01
# 32    2042-02-01                        battery_eol    2041-11-01
#
#                         consumer_name  amount  \
# 0   production of an electric vehicle   588.0
# 1   production of an electric vehicle   588.0
# 2   production of an electric vehicle    84.0
# 3   production of an electric vehicle    80.0
# 4   production of an electric vehicle   280.0
# 5   production of an electric vehicle    84.0
# 6   production of an electric vehicle    80.0
# 7   production of an electric vehicle   280.0
# 8   production of an electric vehicle   168.0
# 9         driving an electric vehicle     0.2
# 10  production of an electric vehicle   168.0
# 11        driving an electric vehicle     0.8
# 12        driving an electric vehicle  1875.0
# 13                                 -1     1.0
# 14        driving an electric vehicle  1875.0
# 15        driving an electric vehicle  1875.0
# 16        driving an electric vehicle  1875.0
# 17        driving an electric vehicle  1875.0
# 18        driving an electric vehicle  1875.0
# 19        driving an electric vehicle  1875.0
# 20        driving an electric vehicle  1875.0
# 21        driving an electric vehicle  1875.0
# 22        driving an electric vehicle  1875.0
# 23        driving an electric vehicle  1875.0
# 24        driving an electric vehicle  1875.0
# 25        driving an electric vehicle  1875.0
# 26        driving an electric vehicle  1875.0
# 27        driving an electric vehicle  1875.0
# 28        driving an electric vehicle  1875.0
# 29        driving an electric vehicle    -1.0
# 30              used electric vehicle  -840.0
# 31              used electric vehicle   -80.0
# 32              used electric vehicle  -280.0
#
#                                temporal_market_shares
# 0   {'background_2020': 0.642, 'background_2030': ...
# 1   {'background_2020': 0.633, 'background_2030': ...
# 2   {'background_2020': 0.542, 'background_2030': ...
# 3   {'background_2020': 0.542, 'background_2030': ...
# 4   {'background_2020': 0.542, 'background_2030': ...
# 5   {'background_2020': 0.533, 'background_2030': ...
# 6   {'background_2020': 0.533, 'background_2030': ...
# 7   {'background_2020': 0.533, 'background_2030': ...
# 8   {'background_2020': 0.442, 'background_2030': ...
# 9                                                None
# 10  {'background_2020': 0.433, 'background_2030': ...
# 11                                               None
# 12  {'background_2020': 0.417, 'background_2030': ...
# 13                                               None
# 14  {'background_2020': 0.317, 'background_2030': ...
# 15  {'background_2020': 0.217, 'background_2030': ...
# 16  {'background_2020': 0.117, 'background_2030': ...
# 17  {'background_2020': 0.017, 'background_2030': ...
# 18  {'background_2030': 0.917, 'background_2040': ...
# 19  {'background_2030': 0.817, 'background_2040': ...
# 20  {'background_2030': 0.717, 'background_2040': ...
# 21  {'background_2030': 0.617, 'background_2040': ...
# 22  {'background_2030': 0.517, 'background_2040': ...
# 23  {'background_2030': 0.417, 'background_2040': ...
# 24  {'background_2030': 0.317, 'background_2040': ...
# 25  {'background_2030': 0.217, 'background_2040': ...
# 26  {'background_2030': 0.117, 'background_2040': ...
# 27  {'background_2030': 0.017, 'background_2040': ...
# 28                             {'background_2040': 1}
# 29                                               None
# 30                             {'background_2040': 1}
# 31                             {'background_2040': 1}
# 32                             {'background_2040': 1}

# %% [markdown]
# Let's understand how `bw_timex` builds the timeline via convolution of the underlying `Temporal_Distributions`. We now zoom in on the production-related part of the timeline and compare the `Temporal_Distributions` of the inputs with the timeline results:

# %%
print(tlca.starting_datetime) # that's the starting time of the FU (driving an electric vehicle)
td_starting_date = TemporalDistribution(date = np.array([tlca.starting_datetime], dtype = "datetime64[M]"), amount=np.array([1])) # turned into TD format
(td_assembly_and_delivery * td_starting_date).graph(resolution = "M")
timeline[(timeline["producer_name"] == "production of an electric vehicle")
         &(timeline["consumer_name"] == "driving an electric vehicle")]
# Out:
# 2025-11-01
#    date_producer                      producer_name date_consumer  \
# 9     2025-08-01  production of an electric vehicle    2025-11-01
# 11    2025-09-01  production of an electric vehicle    2025-11-01
#
#                   consumer_name amount temporal_market_shares
# 9   driving an electric vehicle    0.2                   None
# 11  driving an electric vehicle    0.8                   None

# %% [markdown]
# You can see the delay between `date_consumer` and `date_producer` in the timeline is exactly what the `Temporal_Distribution` foresees. Notice also how the amount in the timeline is adjusted.

# %% [markdown]
# Let's check out a exchange on the second tier: glider production

# %%
td_glider_production.graph(resolution = "M")
timeline[(timeline["producer_name"] == "glider")
        & (timeline["consumer_name"]=="production of an electric vehicle")].sort_values(by="date_consumer")
# Out:
#    date_producer producer_name date_consumer  \
# 0     2023-08-01        glider    2025-08-01
# 2     2024-08-01        glider    2025-08-01
# 8     2025-08-01        glider    2025-08-01
# 1     2023-09-01        glider    2025-09-01
# 5     2024-09-01        glider    2025-09-01
# 10    2025-09-01        glider    2025-09-01
#
#                         consumer_name amount  \
# 0   production of an electric vehicle  588.0
# 2   production of an electric vehicle   84.0
# 8   production of an electric vehicle  168.0
# 1   production of an electric vehicle  588.0
# 5   production of an electric vehicle   84.0
# 10  production of an electric vehicle  168.0
#
#                                temporal_market_shares
# 0   {'background_2020': 0.642, 'background_2030': ...
# 2   {'background_2020': 0.542, 'background_2030': ...
# 8   {'background_2020': 0.442, 'background_2030': ...
# 1   {'background_2020': 0.633, 'background_2030': ...
# 5   {'background_2020': 0.533, 'background_2030': ...
# 10  {'background_2020': 0.433, 'background_2030': ...

# %% [markdown]
# The `Temporal_Distributions` of the glider get "added" to each of the two temporal occurrences of EV production, which is exactly the same as a convolution:

# %%
(td_glider_production * td_assembly_and_delivery * td_starting_date).graph(resolution = "M")
# Out:
# <Axes: xlabel='Date', ylabel='Amount'>

# %% [markdown]
# `bw_timex` performs these convolutions for each exchange in the foreground:

# %% [markdown]
# ```mermaid
# flowchart LR
#     glider_production(glider production):::ei-->|0-2 years prior|ev_production
#     powertrain_production(powertrain production):::ei-->|1 year prior|ev_production
#     battery_production(battery production):::ei-->|1 year prior|ev_production
#     ev_production(ev production):::fg-->|0-3 months prior|driving
#     electricity_generation(electricity generation):::ei-->|uniformly distributed<br/> over lifetime|driving
#     driving(driving):::fg-->|after ev lifetime|used_ev
#     used_ev(used ev):::fg-->|3 months after <br/> ev lifetime|glider_eol(glider eol):::ei
#     used_ev-->|3 months after <br/> ev lifetime|powertrain_eol(powertrain eol):::ei
#     used_ev-->|3 months after <br/> ev lifetime|battery_eol(battery eol):::ei
#
#     classDef ei color:#222832, fill:#3fb1c5, stroke:none;
#     classDef fg color:#222832, fill:#9c5ffd, stroke:none;
# ```

# %% [markdown]
# The timeline then shows us the temporal sequence.

# %%
timeline
# Out:
#    date_producer                      producer_name date_consumer  \
# 0     2023-08-01                             glider    2025-08-01
# 1     2023-09-01                             glider    2025-09-01
# 2     2024-08-01                             glider    2025-08-01
# 3     2024-08-01                         powertrain    2025-08-01
# 4     2024-08-01                            battery    2025-08-01
# 5     2024-09-01                             glider    2025-09-01
# 6     2024-09-01                         powertrain    2025-09-01
# 7     2024-09-01                            battery    2025-09-01
# 8     2025-08-01                             glider    2025-08-01
# 9     2025-08-01  production of an electric vehicle    2025-11-01
# 10    2025-09-01                             glider    2025-09-01
# 11    2025-09-01  production of an electric vehicle    2025-11-01
# 12    2025-11-01                        electricity    2025-11-01
# 13    2025-11-01        driving an electric vehicle    2025-11-01
# 14    2026-11-01                        electricity    2025-11-01
# 15    2027-11-01                        electricity    2025-11-01
# 16    2028-11-01                        electricity    2025-11-01
# 17    2029-11-01                        electricity    2025-11-01
# 18    2030-11-01                        electricity    2025-11-01
# 19    2031-11-01                        electricity    2025-11-01
# 20    2032-11-01                        electricity    2025-11-01
# 21    2033-11-01                        electricity    2025-11-01
# 22    2034-11-01                        electricity    2025-11-01
# 23    2035-11-01                        electricity    2025-11-01
# 24    2036-11-01                        electricity    2025-11-01
# 25    2037-11-01                        electricity    2025-11-01
# 26    2038-11-01                        electricity    2025-11-01
# 27    2039-11-01                        electricity    2025-11-01
# 28    2040-11-01                        electricity    2025-11-01
# 29    2041-11-01              used electric vehicle    2025-11-01
# 30    2042-02-01                         glider_eol    2041-11-01
# 31    2042-02-01                     powertrain_eol    2041-11-01
# 32    2042-02-01                        battery_eol    2041-11-01
#
#                         consumer_name  amount  \
# 0   production of an electric vehicle   588.0
# 1   production of an electric vehicle   588.0
# 2   production of an electric vehicle    84.0
# 3   production of an electric vehicle    80.0
# 4   production of an electric vehicle   280.0
# 5   production of an electric vehicle    84.0
# 6   production of an electric vehicle    80.0
# 7   production of an electric vehicle   280.0
# 8   production of an electric vehicle   168.0
# 9         driving an electric vehicle     0.2
# 10  production of an electric vehicle   168.0
# 11        driving an electric vehicle     0.8
# 12        driving an electric vehicle  1875.0
# 13                                 -1     1.0
# 14        driving an electric vehicle  1875.0
# 15        driving an electric vehicle  1875.0
# 16        driving an electric vehicle  1875.0
# 17        driving an electric vehicle  1875.0
# 18        driving an electric vehicle  1875.0
# 19        driving an electric vehicle  1875.0
# 20        driving an electric vehicle  1875.0
# 21        driving an electric vehicle  1875.0
# 22        driving an electric vehicle  1875.0
# 23        driving an electric vehicle  1875.0
# 24        driving an electric vehicle  1875.0
# 25        driving an electric vehicle  1875.0
# 26        driving an electric vehicle  1875.0
# 27        driving an electric vehicle  1875.0
# 28        driving an electric vehicle  1875.0
# 29        driving an electric vehicle    -1.0
# 30              used electric vehicle  -840.0
# 31              used electric vehicle   -80.0
# 32              used electric vehicle  -280.0
#
#                                temporal_market_shares
# 0   {'background_2020': 0.642, 'background_2030': ...
# 1   {'background_2020': 0.633, 'background_2030': ...
# 2   {'background_2020': 0.542, 'background_2030': ...
# 3   {'background_2020': 0.542, 'background_2030': ...
# 4   {'background_2020': 0.542, 'background_2030': ...
# 5   {'background_2020': 0.533, 'background_2030': ...
# 6   {'background_2020': 0.533, 'background_2030': ...
# 7   {'background_2020': 0.533, 'background_2030': ...
# 8   {'background_2020': 0.442, 'background_2030': ...
# 9                                                None
# 10  {'background_2020': 0.433, 'background_2030': ...
# 11                                               None
# 12  {'background_2020': 0.417, 'background_2030': ...
# 13                                               None
# 14  {'background_2020': 0.317, 'background_2030': ...
# 15  {'background_2020': 0.217, 'background_2030': ...
# 16  {'background_2020': 0.117, 'background_2030': ...
# 17  {'background_2020': 0.017, 'background_2030': ...
# 18  {'background_2030': 0.917, 'background_2040': ...
# 19  {'background_2030': 0.817, 'background_2040': ...
# 20  {'background_2030': 0.717, 'background_2040': ...
# 21  {'background_2030': 0.617, 'background_2040': ...
# 22  {'background_2030': 0.517, 'background_2040': ...
# 23  {'background_2030': 0.417, 'background_2040': ...
# 24  {'background_2030': 0.317, 'background_2040': ...
# 25  {'background_2030': 0.217, 'background_2040': ...
# 26  {'background_2030': 0.117, 'background_2040': ...
# 27  {'background_2030': 0.017, 'background_2040': ...
# 28                             {'background_2040': 1}
# 29                                               None
# 30                             {'background_2040': 1}
# 31                             {'background_2040': 1}
# 32                             {'background_2040': 1}

# %% [markdown]
# **Note**: the amounts in the timeline relate to what is produced if the original reference product amount was consumed, corresponding to the A-matrix elements. This still needs to be multiplied with the actual supply (LCA maths), to get the actual amount consumed at that time step.

# %% [markdown]
# **Note**: The interpolation weights in the timeline (right most column above) specify the share of the amount of an exchange to be sourced from the respective database.
# `None` means that the exchange is in the foreground supply chain, and not at the intersection with the background system.

# %% [markdown]
# ### LCI

# %% [markdown]
# Next, we calculate the time-explicit LCI. The `TimexLCA.lci()` function takes care of all the relinking, based on the information from the timeline.

# %%
tlca.lci()
# Out:
# 2025-11-11 13:29:44.791 | INFO     | bw_timex.timex_lca:lci:360 - Expanding matrices...
# 2025-11-11 13:29:44.924 | INFO     | bw_timex.timex_lca:lci:379 - Calculating dynamic inventory...

# %% [markdown]
# Taking a look at the `dynamic_inventory` that was now created, we can see that it has more rows (emissions) than one - even though CO2 is the only biosphere flow we modeled.
#
# Instead of one row for each emission in the biosphere database we now get one row for each emission at each point in time.

# %%
tlca.dynamic_inventory #rows, #cols
# Out:
# <23x57 sparse matrix of type '<class 'numpy.float64'>'
# 	with 29 stored elements in Compressed Sparse Row format>

# %% [markdown]
# The standard, non-dynamic inventory has far less rows because the temporal resolution is missing. Looking at the timeline again, we see that we have processes at 23 different points in time (only counting the ones that actually directly produce emissions), which exactly matches the ratio of the dimensions of our two inventories:

# %%
tlca.base_lca.inventory.shape # (#rows, #cols)
# Out:
# (1, 24)

# %%
tlca.dynamic_inventory.shape[0]/tlca.base_lca.inventory.shape[0]
# Out:
# 23.0

# %% [markdown]
# While under the hood, the dynamic inventory is calculated as a sparse matrix, there is also a more human-friendly version as a pandas DataFrame:

# %%
tlca.dynamic_inventory_df
# Out:
#          date       amount  flow  activity
# 0  2023-08-01   965.496000     1        26
# 1  2023-09-01  3840.816000     1        27
# 2  2024-08-01   431.760000     1        30
# 3  2024-08-01   246.720000     1        29
# 4  2024-08-01   129.528000     1        28
# 5  2024-09-01  1716.960000     1        33
# 6  2024-09-01   981.120000     1        32
# 7  2024-09-01   515.088000     1        31
# 8  2025-08-01   242.256000     1        34
# 9  2025-09-01   962.976000     1        36
# 10 2025-11-01   664.218750     1        38
# 11 2026-11-01   617.343750     1        40
# 12 2027-11-01   570.468750     1        41
# 13 2028-11-01   523.593750     1        42
# 14 2029-11-01   476.718750     1        43
# 15 2030-11-01   441.515625     1        44
# 16 2031-11-01   408.703126     1        45
# 17 2032-11-01   375.890627     1        46
# 18 2033-11-01   343.078127     1        47
# 19 2034-11-01   310.265628     1        48
# 20 2035-11-01   277.453128     1        49
# 21 2036-11-01   244.640629     1        50
# 22 2037-11-01   211.828129     1        51
# 23 2038-11-01   179.015630     1        52
# 24 2039-11-01   146.203130     1        53
# 25 2040-11-01   140.625006     1        54
# 26 2042-02-01    70.000000     1        58
# 28 2042-02-01     4.200000     1        56
# 27 2042-02-01     0.400000     1        57

# %% [markdown]
# We can make it even more human-friendly by replacing the ids with the names of the biosphere and technosphere flows

# %%
tlca.create_labelled_dynamic_inventory_dataframe()
# Out:
#          date       amount            flow        activity
# 0  2023-08-01   965.496000  carbon dioxide          glider
# 1  2023-09-01  3840.816000  carbon dioxide          glider
# 2  2024-08-01   431.760000  carbon dioxide         battery
# 3  2024-08-01   246.720000  carbon dioxide      powertrain
# 4  2024-08-01   129.528000  carbon dioxide          glider
# 5  2024-09-01  1716.960000  carbon dioxide         battery
# 6  2024-09-01   981.120000  carbon dioxide      powertrain
# 7  2024-09-01   515.088000  carbon dioxide          glider
# 8  2025-08-01   242.256000  carbon dioxide          glider
# 9  2025-09-01   962.976000  carbon dioxide          glider
# 10 2025-11-01   664.218750  carbon dioxide     electricity
# 11 2026-11-01   617.343750  carbon dioxide     electricity
# 12 2027-11-01   570.468750  carbon dioxide     electricity
# 13 2028-11-01   523.593750  carbon dioxide     electricity
# 14 2029-11-01   476.718750  carbon dioxide     electricity
# 15 2030-11-01   441.515625  carbon dioxide     electricity
# 16 2031-11-01   408.703126  carbon dioxide     electricity
# 17 2032-11-01   375.890627  carbon dioxide     electricity
# 18 2033-11-01   343.078127  carbon dioxide     electricity
# 19 2034-11-01   310.265628  carbon dioxide     electricity
# 20 2035-11-01   277.453128  carbon dioxide     electricity
# 21 2036-11-01   244.640629  carbon dioxide     electricity
# 22 2037-11-01   211.828129  carbon dioxide     electricity
# 23 2038-11-01   179.015630  carbon dioxide     electricity
# 24 2039-11-01   146.203130  carbon dioxide     electricity
# 25 2040-11-01   140.625006  carbon dioxide     electricity
# 26 2042-02-01    70.000000  carbon dioxide     battery_eol
# 28 2042-02-01     4.200000  carbon dioxide      glider_eol
# 27 2042-02-01     0.400000  carbon dioxide  powertrain_eol

# %% [markdown]
# If we are only interested in the new overall time-explicit scores and don't care about the timing of the emissions, we can set `build_dynamic_biosphere=False` (default is `True`), which saves time and memory. In that case, you only get the `TimexLCA.lca.inventory`, but not the `TimexLCA.dynamic_inventory`.

# %% [markdown]
# LCIA

# %% [markdown]
# In case the timing of emissions is not important, one can directly calculate the LCIA the "standard way" using static characterization methods. Per default, the following calculates the static lcia score based on the impact method chosen in the very beginning:

# %%
tlca.static_lcia()
tlca.static_score   #kg CO2-eq
# Out:
# 16038.882535268815

# %% [markdown]
# At this point, we can already compare these time-explicit results to the results of an "ordinary", completely static LCA. These already exist within the TimexLCA class, originally calculated to set the priorities for the graph traversal:

# %%
tlca.base_lca.score
# Out:
# 28089.199999794364

# %% [markdown]
# By linking to the progressively 'cleaner' inventories in the future databases the time-explicit score is much lower than the conventional LCA score, for the same static impact assessment method.

# %% [markdown]
# ### NEW: Waterfall plots
# based on the questions after the workshop, we wanted to add the visualization of the "waterfall" to better explain what exactly is the difference between a time-explicit LCA score and a normal LCA score
#
# **Note:** the waterfall plotting is currently only possible after dynamic characterization. But we can force very similar results from dynamic_characterization compared to static GWP100 by giving input arguments that resemble how GWP100 is usually calculated.

# %%
from bw_timex.utils import plot_characterized_inventory_as_waterfall

from dynamic_characterization.ipcc_ar6.radiative_forcing import characterize_co2 # dynamic characterization function for CO2

characterization_functions_co2 = {
    bd.get_node(code="CO2").id: characterize_co2, #mapping it to "our" CO2 flow
}
tlca.dynamic_lcia(metric="GWP", characterization_functions=characterization_functions_co2) #default arguments correspond to GWP100
# Out:
#          date       amount  flow  activity
# 0  2024-01-01   965.496000     1        26
# 1  2024-01-01  3840.816000     1        27
# 2  2025-01-01   129.528000     1        28
# 3  2025-01-01   246.720000     1        29
# 4  2025-01-01   431.760000     1        30
# 5  2025-01-01   515.088000     1        31
# 6  2025-01-01   981.120000     1        32
# 7  2025-01-01  1716.960000     1        33
# 8  2026-01-01   242.256000     1        34
# 9  2026-01-01   664.218750     1        38
# 10 2026-01-01   962.976000     1        36
# 11 2027-01-01   617.343750     1        40
# 12 2028-01-01   570.468750     1        41
# 13 2029-01-01   523.593750     1        42
# 14 2030-01-01   476.718750     1        43
# 15 2031-01-01   441.515625     1        44
# 16 2032-01-01   408.703126     1        45
# 17 2033-01-01   375.890627     1        46
# 18 2034-01-01   343.078127     1        47
# 19 2035-01-01   310.265628     1        48
# 20 2036-01-01   277.453128     1        49
# 21 2037-01-01   244.640629     1        50
# 22 2038-01-01   211.828129     1        51
# 23 2039-01-01   179.015630     1        52
# 24 2040-01-01   146.203130     1        53
# 25 2041-01-01   140.625006     1        54
# 26 2042-01-01     0.400000     1        57
# 27 2042-01-01     4.200000     1        56
# 28 2042-01-01    70.000000     1        58

# %% [markdown]
# For comparison, we want to add the normal LCA results (corresponds in our current setup to a "2020"-LCA). The total score is already available via tlca.base_lca.score, but we would like to show the contribution by processes, so we calculate the static scores again per process.

# %%
import bw2calc as bc
static_score = {}
lca = bc.LCA({driving.key: 1}, method)
lca.lci()
for exc in driving.technosphere(): #foreground connected currently to db_2020
        if exc.input["name"] in (
            ev_production["name"],
            used_ev["name"],
        ):
            for subexc in exc.input.technosphere():
                lca.lcia(
                    demand={
                        subexc.input.id: exc.amount
                        * subexc.amount
                        * subexc.input.rp_exchange().amount
                    }
                )
                static_score[subexc.input["name"]] = lca.score
        else:
            lca.lcia(demand={exc.input.id: exc.amount})
            static_score[exc.input["name"]] = lca.score # add

# %%
#manually aggregating the time-explicit score as the waterfall plot doesn't have a internal sum-function, yet.
tlca_score_stacked = (
    tlca.characterized_inventory
        .assign(activity_label=lambda df: df["activity"].map(
            {a: tlca.get_activity_name_from_time_mapped_id(a)
             for a in df["activity"].unique()}
        ))
        .drop(columns=["date"])
).groupby("activity_label").sum().drop(columns=["flow", "activity"])

tlca_score_stacked= tlca_score_stacked.to_dict()["amount"]
tlca_score_stacked
# Out:
# {'battery': 2148.7200000000003,
#  'battery_eol': 70.00000000000001,
#  'electricity': 5931.562535371631,
#  'glider': 6656.16,
#  'glider_eol': 4.1999999061226845,
#  'powertrain': 1227.8400000000004,
#  'powertrain_eol': 0.39999999105930334}

# %%
plot_characterized_inventory_as_waterfall(tlca, static_score, tlca_score_stacked)

# %% [markdown]
# What do you see:
#
# - On the left you see a normal LCA, we also call it static LCA. In this case it uses the 2020 background databases
# - On the middle you can see the time-explicit LCA score, spread across years.
# - on the right, you see the **sum of the time-explicit results**, not a prospective score (!!). I didn't want to change the source code of the plotting method, and it doesn't have a sum-display function (yet). So please don't be confused by the wrong label.
#
# You can of course feed it a prospective LCA score, by changing the database to which your foreground system links to at the top of the notebook.

# %% [markdown]
# ## Dynamic LCIA
# In addition to the standard static characterization, the time-explicit, dynamic inventory generated by a `TimexLCA` allows for dynamic characterization.
#
#
# This is out of scope of the this 1-hour workshop, but you can check out the following resources on dynamic characterization in your own time:
# - at the bottom of [original EV notebook](https://github.com/brightway-lca/bw_timex/blob/main/notebooks/example_electric_vehicle_standalone.ipynb),
# - a separate, [simple example on dynamic characterization](https://github.com/TimoDiepers/timex/blob/main/notebooks/example_simple_dynamic_characterization.ipynb),
# - or the separate (but fully compatible) package [dynamic_characterization](https://dynamic-characterization.readthedocs.io/en/latest/).
#
#
# ## Timex and dynamic MFA
#
# For further explore the intersection between `bw_timex` and dynamic MFA, see Bonus exercise 2 (modelling a car fleet) at the end of [electric vs petrol vehicle](https://github.com/brightway-lca/bw_timex/blob/main/notebooks/teaching/teaching_project_electric_vs_petrol_vehicle_premise_with_solutions.ipynb).
