# %% [markdown]
# # `timex` example: Cradle-to-grave LCA of an electric vehicle

# %%
import bw2data as bd

bd.projects.set_current("bw25_premise")

# %% [markdown]
# ## Prospective databases
#
# Created using `premise` with updated electricity sectors

# %%
db_2020 = bd.Database("db_2020")
db_2030 = bd.Database("db_2030")
db_2040 = bd.Database("db_2040")

# %% [markdown]
# ## Case study setup

# %%
del bd.databases["foreground"]
foreground = bd.Database("foreground")
foreground.write({})

# %% [markdown]
# Getting some input processes with positive and negative carbon dioxide flows

# %%
# a process with carbon dioxide to soil flow (uptake by soil)
land_use_change = [act for act in db_2020 if "land already in use, annual cropland to perennial crop" in act["name"] and  act["location"] == "ES"][0]
for exc in land_use_change.biosphere():
    print(exc)
# Out:
# Exchange: 1.8148820400238037 square meter 'Transformation, from arable land, unspecified use' (square meter, None, ('natural resource', 'land')) to 'land already in use, annual cropland to perennial crop' (kilogram, ES, None)>
# Exchange: 1.8148820400238037 square meter 'Transformation, to permanent crop' (square meter, None, ('natural resource', 'land')) to 'land already in use, annual cropland to perennial crop' (kilogram, ES, None)>
# Exchange: 28.747732162475586 kilogram 'Carbon dioxide, to soil or biomass stock' (kilogram, None, ('soil',)) to 'land already in use, annual cropland to perennial crop' (kilogram, ES, None)>

# %%
fg = bd.Database("foreground")

# %%
fg.new_node("dummy system", name="dummy system", unit="unit").save()
dummy_node = fg.get("dummy system")
dummy_node.new_edge(input=dummy_node, amount=1, type="production").save()

# %%
from bw_temporalis import TemporalDistribution, easy_timedelta_distribution
import numpy as np

#add some co2 uptake
land_use_node = dummy_node.new_edge(input=land_use_change, amount=10, type="technosphere")
land_use_node["temporal_distribution"] = TemporalDistribution(
    date=np.array([-10, -5, 0, 5], dtype="timedelta64[Y]"), 
    amount=np.array([0.25, 0.25, 0.25, 0.25])  
)
land_use_node.save()

# %%
#adding some co2 emissions
co2_flow=bd.Database("biosphere3").search("Carbon dioxide, fossil")[0]

co2_node = dummy_node.new_edge(input=co2_flow, amount=50, type="biosphere")
co2_node["temporal_distribution"]=TemporalDistribution(
    date=np.array([-8, 8], dtype="timedelta64[Y]"), 
    amount=np.array([0.5, 0.5])  
)
co2_node.save()

# %% [markdown]
# ## LCA using `timex`

# %%
method = ("EF v3.1", "climate change", "global warming potential (GWP100)")

# %%
from datetime import datetime

database_date_dict = {
    "db_2020": datetime.strptime("2020", "%Y"),
    "db_2030": datetime.strptime("2030", "%Y"),
    "db_2040": datetime.strptime("2040", "%Y"),
    "foreground": "dynamic",  # flag databases that should be temporally distributed with "dynamic"
}

# %%
from timex_lca import TimexLCA

tlca = TimexLCA({dummy_node.key: 1}, method, database_date_dict, cutoff=1e-9)
# Out:
# c:\users\mullera\onedrive - vito\documents\04_coding\tictac_lca\timex_lca\timex_lca.py:86: UserWarning: No edge filter function provided. Skipping all edges within background databases.
#   warnings.warn(
# Starting graph traversal
# Calculation count: 1

# %%
tlca.build_timeline()
# Out:
# c:\users\mullera\onedrive - vito\documents\04_coding\tictac_lca\timex_lca\timeline_builder.py:317: Warning: Reference date 2014-01-01 00:00:00 is lower than all provided dates. Data will be taken from the closest higher year.
#   warnings.warn(
# c:\users\mullera\onedrive - vito\documents\04_coding\tictac_lca\timex_lca\timeline_builder.py:317: Warning: Reference date 2019-01-01 00:00:00 is lower than all provided dates. Data will be taken from the closest higher year.
#   warnings.warn(
#   date_producer                                      producer_name  \
# 0    2014-01-01  land already in use, annual cropland to perenn...
# 1    2019-01-01  land already in use, annual cropland to perenn...
# 2    2024-01-01  land already in use, annual cropland to perenn...
# 3    2024-01-01                                       dummy system
# 4    2029-01-01  land already in use, annual cropland to perenn...
#
#   date_consumer consumer_name amount  \
# 0    2024-01-01  dummy system    2.5
# 1    2024-01-01  dummy system    2.5
# 2    2024-01-01  dummy system    2.5
# 3    2024-01-01            -1    1.0
# 4    2024-01-01  dummy system    2.5
#
#                                interpolation_weights
# 0                                     {'db_2020': 1}
# 1                                     {'db_2020': 1}
# 2  {'db_2020': 0.6000547495209416, 'db_2030': 0.3...
# 3  {'db_2020': 0.6000547495209416, 'db_2030': 0.3...
# 4  {'db_2020': 0.09991787571858746, 'db_2030': 0....

# %%
tlca.lci()

# %%
tlca.static_lcia()
tlca.score
# Out:
# -237.47732162475586

# %%
tlca.dynamic_lcia(metric="radiative_forcing", fixed_TH=False) # default characterization function dictionaries mapping to biosphere3 flows from static LCIA method now calculated inside the method
# Out:
# c:\users\mullera\onedrive - vito\documents\04_coding\tictac_lca\timex_lca\dynamic_characterization.py:58: UserWarning: No custom dynamic characterization functions provided.
# Using default dynamic characterization functions for CO2, CH4, N2O, CO with decay functions from IPCC AR6.
# The selected biosphere flows for these GHGs are based on the selection of the currently chosen impact category: ('EF v3.1', 'climate change', 'global warming potential (GWP100)') and their matrix ids can be looked up with .characterization_functions.keys()
#   warnings.warn(
#                    date        amount  flow  \
# 0   2014-01-01 00:00:00  0.000000e+00  3636
# 1   2015-01-01 05:49:12 -1.183833e-13  3636
# 2   2016-01-01 01:26:24  0.000000e+00  1170
# 3   2016-01-01 11:38:24 -1.111291e-13  3636
# 4   2016-12-31 07:15:36  4.118006e-14  1170
# ..                  ...           ...   ...
# 696 2128-01-02 00:10:48 -1.800239e-31  1170
# 695 2128-01-02 00:10:48 -5.034345e-14  3636
# 697 2128-12-31 11:06:00  1.759567e-14  1170
# 698 2129-12-31 16:55:12  1.755357e-14  1170
# 699 2130-12-31 22:44:24  1.751215e-14  1170
#
#                                     flow_name  activity  \
# 0    Carbon dioxide, to soil or biomass stock     39919
# 1    Carbon dioxide, to soil or biomass stock     39919
# 2                      Carbon dioxide, fossil     98280
# 3    Carbon dioxide, to soil or biomass stock     39919
# 4                      Carbon dioxide, fossil     98280
# ..                                        ...       ...
# 696                    Carbon dioxide, fossil     39919
# 695  Carbon dioxide, to soil or biomass stock     39919
# 697                    Carbon dioxide, fossil     98280
# 698                    Carbon dioxide, fossil     98280
# 699                    Carbon dioxide, fossil     98280
#
#                                    activity_name    amount_sum
# 0    (db_2020, a72f0604c64853d294b3010497d0d38d)  0.000000e+00
# 1    (db_2020, a72f0604c64853d294b3010497d0d38d) -1.183833e-13
# 2                     (foreground, dummy system) -1.183833e-13
# 3    (db_2020, a72f0604c64853d294b3010497d0d38d) -2.295124e-13
# 4                     (foreground, dummy system) -1.883323e-13
# ..                                           ...           ...
# 696  (db_2020, a72f0604c64853d294b3010497d0d38d) -2.108455e-11
# 695  (db_2020, a72f0604c64853d294b3010497d0d38d) -2.108455e-11
# 697                   (foreground, dummy system) -2.106696e-11
# 698                   (foreground, dummy system) -2.104940e-11
# 699                   (foreground, dummy system) -2.103189e-11
#
# [700 rows x 7 columns]

# %%
tlca.plot_dynamic_characterized_inventory(sum_emissions_within_activity=True) #jump in orange dots comes from summing up the emissions within the activity=True

# %%
tlca.dynamic_lcia(metric="GWP", fixed_TH=False) #negative flows for biogenic CO2 uptake
# Out:
# c:\users\mullera\onedrive - vito\documents\04_coding\tictac_lca\timex_lca\dynamic_characterization.py:58: UserWarning: No custom dynamic characterization functions provided.
# Using default dynamic characterization functions for CO2, CH4, N2O, CO with decay functions from IPCC AR6.
# The selected biosphere flows for these GHGs are based on the selection of the currently chosen impact category: ('EF v3.1', 'climate change', 'global warming potential (GWP100)') and their matrix ids can be looked up with .characterization_functions.keys()
#   warnings.warn(
# c:\users\mullera\onedrive - vito\documents\04_coding\tictac_lca\timex_lca\dynamic_characterization.py:212: UserWarning: Using timex' default co2 characterization function for GWP reference.
#   warnings.warn(
# c:\users\mullera\onedrive - vito\documents\04_coding\tictac_lca\timex_lca\dynamic_characterization.py:212: UserWarning: Using timex' default co2 characterization function for GWP reference.
#   warnings.warn(
# c:\users\mullera\onedrive - vito\documents\04_coding\tictac_lca\timex_lca\dynamic_characterization.py:212: UserWarning: Using timex' default co2 characterization function for GWP reference.
#   warnings.warn(
# c:\users\mullera\onedrive - vito\documents\04_coding\tictac_lca\timex_lca\dynamic_characterization.py:212: UserWarning: Using timex' default co2 characterization function for GWP reference.
#   warnings.warn(
# c:\users\mullera\onedrive - vito\documents\04_coding\tictac_lca\timex_lca\dynamic_characterization.py:212: UserWarning: Using timex' default co2 characterization function for GWP reference.
#   warnings.warn(
# c:\users\mullera\onedrive - vito\documents\04_coding\tictac_lca\timex_lca\dynamic_characterization.py:212: UserWarning: Using timex' default co2 characterization function for GWP reference.
#   warnings.warn(
# c:\users\mullera\onedrive - vito\documents\04_coding\tictac_lca\timex_lca\dynamic_characterization.py:212: UserWarning: Using timex' default co2 characterization function for GWP reference.
#   warnings.warn(
#                  date        amount  flow  \
# 0 2014-01-01 00:00:00 -7.186933e+01  3636
# 1 2016-01-01 01:26:24  2.500000e+01  1170
# 2 2019-01-01 00:00:00 -7.186933e+01  3636
# 3 2024-01-01 00:00:00 -7.186933e+01  3636
# 4 2029-01-01 00:00:00 -7.186933e+01  3636
# 5 2029-01-01 00:00:00 -2.569987e-16  1170
# 6 2031-12-31 22:33:36  2.500000e+01  1170
#
#                                   flow_name  activity  \
# 0  Carbon dioxide, to soil or biomass stock     39919
# 1                    Carbon dioxide, fossil     98280
# 2  Carbon dioxide, to soil or biomass stock     39919
# 3  Carbon dioxide, to soil or biomass stock     39919
# 4  Carbon dioxide, to soil or biomass stock     39919
# 5                    Carbon dioxide, fossil     39919
# 6                    Carbon dioxide, fossil     98280
#
#                                  activity_name  amount_sum
# 0  (db_2020, a72f0604c64853d294b3010497d0d38d)  -71.869330
# 1                   (foreground, dummy system)  -46.869330
# 2  (db_2020, a72f0604c64853d294b3010497d0d38d) -118.738661
# 3  (db_2020, a72f0604c64853d294b3010497d0d38d) -190.607991
# 4  (db_2020, a72f0604c64853d294b3010497d0d38d) -262.477322
# 5  (db_2020, a72f0604c64853d294b3010497d0d38d) -262.477322
# 6                   (foreground, dummy system) -237.477322

# %%
tlca.characterized_inventory
# Out:
#                  date        amount  flow  \
# 0 2014-01-01 00:00:00 -7.186933e+01  3636
# 1 2016-01-01 01:26:24  2.500000e+01  1170
# 2 2019-01-01 00:00:00 -7.186933e+01  3636
# 3 2024-01-01 00:00:00 -7.186933e+01  3636
# 4 2029-01-01 00:00:00 -7.186933e+01  3636
# 5 2029-01-01 00:00:00 -2.569987e-16  1170
# 6 2031-12-31 22:33:36  2.500000e+01  1170
#
#                                   flow_name  activity  \
# 0  Carbon dioxide, to soil or biomass stock     39919
# 1                    Carbon dioxide, fossil     98280
# 2  Carbon dioxide, to soil or biomass stock     39919
# 3  Carbon dioxide, to soil or biomass stock     39919
# 4  Carbon dioxide, to soil or biomass stock     39919
# 5                    Carbon dioxide, fossil     39919
# 6                    Carbon dioxide, fossil     98280
#
#                                  activity_name  amount_sum
# 0  (db_2020, a72f0604c64853d294b3010497d0d38d)  -71.869330
# 1                   (foreground, dummy system)  -46.869330
# 2  (db_2020, a72f0604c64853d294b3010497d0d38d) -118.738661
# 3  (db_2020, a72f0604c64853d294b3010497d0d38d) -190.607991
# 4  (db_2020, a72f0604c64853d294b3010497d0d38d) -262.477322
# 5  (db_2020, a72f0604c64853d294b3010497d0d38d) -262.477322
# 6                   (foreground, dummy system) -237.477322

# %%
tlca.dynamic_inventory_characterizer.characterization_functions #available functions
# Out:
# {1169: (<function timex_lca.dynamic_characterization.characterize_co2(series, period: int | None = 100, cumulative: bool | None = False, negative_sign: bool | None = False) -> pandas.core.frame.DataFrame>,
#   False),
#  1170: (<function timex_lca.dynamic_characterization.characterize_co2(series, period: int | None = 100, cumulative: bool | None = False, negative_sign: bool | None = False) -> pandas.core.frame.DataFrame>,
#   False),
#  1168: (<function timex_lca.dynamic_characterization.characterize_co2(series, period: int | None = 100, cumulative: bool | None = False, negative_sign: bool | None = False) -> pandas.core.frame.DataFrame>,
#   False),
#  1171: (<function timex_lca.dynamic_characterization.characterize_co2(series, period: int | None = 100, cumulative: bool | None = False, negative_sign: bool | None = False) -> pandas.core.frame.DataFrame>,
#   False),
#  112: (<function timex_lca.dynamic_characterization.characterize_co2(series, period: int | None = 100, cumulative: bool | None = False, negative_sign: bool | None = False) -> pandas.core.frame.DataFrame>,
#   False),
#  3635: (<function timex_lca.dynamic_characterization.characterize_co2(series, period: int | None = 100, cumulative: bool | None = False, negative_sign: bool | None = False) -> pandas.core.frame.DataFrame>,
#   False),
#  3640: (<function timex_lca.dynamic_characterization.characterize_co2(series, period: int | None = 100, cumulative: bool | None = False, negative_sign: bool | None = False) -> pandas.core.frame.DataFrame>,
#   False),
#  3642: (<function timex_lca.dynamic_characterization.characterize_co2(series, period: int | None = 100, cumulative: bool | None = False, negative_sign: bool | None = False) -> pandas.core.frame.DataFrame>,
#   False),
#  3632: (<function timex_lca.dynamic_characterization.characterize_co2(series, period: int | None = 100, cumulative: bool | None = False, negative_sign: bool | None = False) -> pandas.core.frame.DataFrame>,
#   False),
#  3643: (<function timex_lca.dynamic_characterization.characterize_co2(series, period: int | None = 100, cumulative: bool | None = False, negative_sign: bool | None = False) -> pandas.core.frame.DataFrame>,
#   False),
#  3717: (<function timex_lca.dynamic_characterization.characterize_co2(series, period: int | None = 100, cumulative: bool | None = False, negative_sign: bool | None = False) -> pandas.core.frame.DataFrame>,
#   True),
#  3745: (<function timex_lca.dynamic_characterization.characterize_co2(series, period: int | None = 100, cumulative: bool | None = False, negative_sign: bool | None = False) -> pandas.core.frame.DataFrame>,
#   True),
#  3719: (<function timex_lca.dynamic_characterization.characterize_co2(series, period: int | None = 100, cumulative: bool | None = False, negative_sign: bool | None = False) -> pandas.core.frame.DataFrame>,
#   True),
#  3636: (<function timex_lca.dynamic_characterization.characterize_co2(series, period: int | None = 100, cumulative: bool | None = False, negative_sign: bool | None = False) -> pandas.core.frame.DataFrame>,
#   True),
#  1650: (<function timex_lca.dynamic_characterization.characterize_ch4(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#   False),
#  1651: (<function timex_lca.dynamic_characterization.characterize_ch4(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#   False),
#  1649: (<function timex_lca.dynamic_characterization.characterize_ch4(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#   False),
#  1652: (<function timex_lca.dynamic_characterization.characterize_ch4(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#   False),
#  438: (<function timex_lca.dynamic_characterization.characterize_ch4(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#   False),
#  3631: (<function timex_lca.dynamic_characterization.characterize_ch4(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#   False),
#  3633: (<function timex_lca.dynamic_characterization.characterize_ch4(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#   False),
#  3630: (<function timex_lca.dynamic_characterization.characterize_ch4(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#   False),
#  3637: (<function timex_lca.dynamic_characterization.characterize_ch4(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#   False),
#  3644: (<function timex_lca.dynamic_characterization.characterize_ch4(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#   False),
#  4686: (<function timex_lca.dynamic_characterization.characterize_n2o(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#   False),
#  4687: (<function timex_lca.dynamic_characterization.characterize_n2o(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#   False),
#  4685: (<function timex_lca.dynamic_characterization.characterize_n2o(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#   False),
#  4688: (<function timex_lca.dynamic_characterization.characterize_n2o(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#   False),
#  4684: (<function timex_lca.dynamic_characterization.characterize_n2o(series, period: int = 100, cumulative=False) -> pandas.core.frame.DataFrame>,
#   False)}

# %%
tlca.plot_dynamic_characterized_inventory(
    sum_emissions_within_activity=True, cumsum=False
)

# %%
tlca.plot_dynamic_characterized_inventory(
    sum_emissions_within_activity=True, cumsum=False
)

#TODO understand why it doesn't work in this cell
# Out:
# ---------------------------------------------------------------------------
# UnknownObject                             Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 tlca.plot_dynamic_characterized_inventory(
#       2     sum_emissions_within_activity=True, cumsum=False
#       3 )
#
# File c:\users\mullera\onedrive - vito\documents\04_coding\tictac_lca\timex_lca\timex_lca.py:796, in TimexLCA.plot_dynamic_characterized_inventory(self, cumsum, sum_emissions_within_activity, sum_activities)
#     793     plot_data["activity_label"] = "All activities"
#     795 else:
# --> 796     plot_data["activity_label"] = plot_data.apply(
#     797         lambda row: bd.get_activity(row["activity_name"])["name"], axis=1
#     798     )
#     800 # Determine the plotting labels and titles based on the characterization method
#     801 if self.type_of_method == "radiative_forcing":
#
# File c:\Users\MULLERA\AppData\Local\anaconda3\envs\timex_3\Lib\site-packages\pandas\core\frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\MULLERA\AppData\Local\anaconda3\envs\timex_3\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File c:\Users\MULLERA\AppData\Local\anaconda3\envs\timex_3\Lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File c:\Users\MULLERA\AppData\Local\anaconda3\envs\timex_3\Lib\site-packages\pandas\core\apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# File c:\users\mullera\onedrive - vito\documents\04_coding\tictac_lca\timex_lca\timex_lca.py:797, in TimexLCA.plot_dynamic_characterized_inventory.<locals>.<lambda>(row)
#     793     plot_data["activity_label"] = "All activities"
#     795 else:
#     796     plot_data["activity_label"] = plot_data.apply(
# --> 797         lambda row: bd.get_activity(row["activity_name"])["name"], axis=1
#     798     )
#     800 # Determine the plotting labels and titles based on the characterization method
#     801 if self.type_of_method == "radiative_forcing":
#
# File c:\Users\MULLERA\AppData\Local\anaconda3\envs\timex_3\Lib\site-packages\bw2data\utils.py:440, in get_activity(key, **kwargs)
#     438 elif isinstance(key, numbers.Integral):
#     439     kwargs["id"] = key
# --> 440 return get_node(**kwargs)
#
# File c:\Users\MULLERA\AppData\Local\anaconda3\envs\timex_3\Lib\site-packages\bw2data\utils.py:422, in get_node(**kwargs)
#     418     raise MultipleResults(
#     419         "Found {} results for the given search".format(len(candidates))
#     420     )
#     421 elif not candidates:
# --> 422     raise UnknownObject
#     423 return candidates[0]
#
# UnknownObject:
